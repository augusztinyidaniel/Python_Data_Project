# %% [markdown]
# # Create a variable
#
# ```python
# variable_name = value
# ```

# %%
salary = 100000

# %%
salary
# Out:
# 100000

# %%
"salary"
# Out:
# 'salary'

# %% [markdown]
# # Calculate the Following
#
# Total Salary = (Base Salary) * (1 + Bonus Rate)

# %%
base_salary = 100000
bonus_rate = .10

# %%
total_salary = (base_salary) * (1 + bonus_rate)

# %%
total_salary
# Out:
# 110000.00000000001

# %% [markdown]
# Variable names have to be numbers, letters, underscores. No spaces or apostrophes.

# %%
lukes salary = 100000
# Out:
#   File "<ipython-input-7-23e85ed41d37>", line 1
#     lukes salary = 100000
#           ^
# SyntaxError: invalid syntax

# %%
luke's_salary = 100000
# Out:
#   File "<ipython-input-8-6c7d7cdb7d7b>", line 1
#     luke's_salary = 100000
#         ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# # Variables aren't only numbers
#
# ### Example
# - Create variables to store the following information about a job posting:
#   - Job ID (integer)
#   - Company Name (string)
#   - Salary Rate (string, but consider how you might store this as a numerical type for calculations)
#   - Job Work From Home (boolean)

# %%
company_name = 'DataWiz Inc.'

# %%
company_name
# Out:
# 'DataWiz Inc.'

# %%
job_wfh = True

# %%
job_wfh
# Out:
# True

# %%
job_id = 101
job_title = 'Data Analyst'
job_salary = 125000

# %%
print("Data Job Description")
print("++++++++++++++++++++")
print("Job ID:      ", job_id)
print("Company Name:", company_name)
print("Job Title:   ", job_title)
print("Salary:      ", job_salary)
print("WFH:         ", job_wfh)
# Out:
# Data Job Description
# ++++++++++++++++++++
# Job ID:       101
# Company Name: DataWiz Inc.
# Job Title:    Data Analyst
# Salary:       125000
# WFH:          True
